# %%
class Database:
    def __init__(self):
        self.host = '0.0.0'

# %%
config = Database()
config.host
# Out:
# '0.0.0'

# %%
class Singleton:
    _instance = None

    def __new__(cls, *args, **kwargs):
        if cls._instance is None:
            cls._instance = super().__new__(cls)
        return cls._instance

# %%
s = Singleton()
s2 = Singleton()
s is s2
# Out:
# True

# %%
class DataBase:
    _instance = None

    def __new__(cls, *args, **kwargs):
        if cls._instance is None:
            cls._instance = super().__new__(cls)
        return cls._instance
    
    def __init__(self,connect_str = None):
        if not hasattr(self,'connect_str'):
            self.connect_str = connect_str or 'default'
            self._initialized = True

    def query(self,sql):
        print(sql)
    
dba = DataBase('mysql://root:123456@localhost:3306/test')
db2 = DataBase('mysql://root:123456@localhost:3306/test2')
db2 is dba
dba.query('select * from user')
# Out:
# select * from user

# %%
def singleton(cls):
    instances = {}
    def wapper(*arg,**kwargs):
        print(*arg,kwargs)
        if cls not in instances:
            instances[cls] = cls(*arg,**kwargs)
        return instances[cls]
    return wapper
@singleton
class Logger:
    def __init__(self,a,b,c={"a":2}):
        self.level = 'INFO'
        self.handers =[]
    
    def log(self,message):
        print(f"[self.level] {message}")

logger = Logger(1,3,c={"a":23})
logger.log('hello world')
logger2 = Logger()
logger2.log('hello world2')
logger2 is logger
# Out:
# 1 3 {'c': {'a': 23}}
# [self.level] hello world
# {}
# [self.level] hello world2
# True
